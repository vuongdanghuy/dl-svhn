# %%
# !pip uninstall -y tensorflow
# Out:
# Uninstalling tensorflow-2.4.0:
#   Successfully uninstalled tensorflow-2.4.0

# %%
# !pip install tensorflow-gpu==1.14.0
# Out:
# ...
#      |████████████████████████████████| 377.0MB 43kB/s
# ...
#      |████████████████████████████████| 3.2MB 49.9MB/s
# ...
#      |████████████████████████████████| 491kB 49.2MB/s
# ...
#      |████████████████████████████████| 51kB 7.0MB/s
# ...
#   Found existing installation: tensorboard 2.4.0
#     Uninstalling tensorboard-2.4.0:
#       Successfully uninstalled tensorboard-2.4.0
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
#       Successfully uninstalled tensorflow-estimator-2.4.0
# ...

# %%
# !pip install keras==2.2
# Out:
# ...
#      |████████████████████████████████| 307kB 9.1MB/s
# ...
#      |████████████████████████████████| 51kB 7.9MB/s
# ERROR: fancyimpute 0.4.3 requires tensorflow, which is not installed.
# ERROR: tensorflow-gpu 1.14.0 has requirement keras-applications>=1.0.6, but you'll have keras-applications 1.0.2 which is incompatible.
# ERROR: tensorflow-gpu 1.14.0 has requirement keras-preprocessing>=1.0.5, but you'll have keras-preprocessing 1.0.1 which is incompatible.
# ...
#   Found existing installation: Keras-Preprocessing 1.1.2
#     Uninstalling Keras-Preprocessing-1.1.2:
#       Successfully uninstalled Keras-Preprocessing-1.1.2
#   Found existing installation: Keras-Applications 1.0.8
#     Uninstalling Keras-Applications-1.0.8:
#       Successfully uninstalled Keras-Applications-1.0.8
#   Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# ...

# %%
import tensorflow as tf
tf.__version__
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/keras-frcnn
# Out:
# /content/drive/MyDrive/keras-frcnn

# %%
# !unrar x ./data/val.rar /content/
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from ./data/val.rar
#
# Creating    /content/val                                              OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
# !python train_frcnn_copy.py -o simple -p ./data/train.txt -v ./data/val.txt --network vgg --num_epochs 100 --input_weight_path ./model_frcnn_0005.hdf5
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !python test_frcnn.py -p /content/test -n 32 --network vgg
# Out:
# Streaming output truncated to the last 5000 lines.
# 171004.png
# 171017.png
# 171018.png
# 171033.png
# 171050.png
# 171067.png
# 171085.png
# 171095.png
# 171098.png
# 171099.png
# 171100.png
# 171109.png
# 171112.png
# 171120.png
# 171126.png
# 171141.png
# 171149.png
# 171159.png
# 171185.png
# 171205.png
# 171207.png
# 171214.png
# 171215.png
# 171219.png
# 171220.png
# 171223.png
# 171233.png
# 171235.png
# 171257.png
# 171269.png
# 171274.png
# 171285.png
# 171286.png
# 171296.png
# 171314.png
# 171317.png
# 171325.png
# 171327.png
# 171335.png
# 171341.png
# 171366.png
# 171369.png
# 171378.png
# 171398.png
# 171402.png
# 171417.png
# 171423.png
# 171425.png
# 171438.png
# 171443.png
# 171449.png
# 171450.png
# 171452.png
# 171457.png
# 171458.png
# 171462.png
# 171476.png
# 171483.png
# 171486.png
# 171488.png
# 171489.png
# 171491.png
# 171504.png
# 171510.png
# 171512.png
# 171523.png
# 171526.png
# 171529.png
# 171530.png
# 171544.png
# 171545.png
# 171557.png
# ...
